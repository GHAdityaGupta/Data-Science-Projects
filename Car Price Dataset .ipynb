# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %% [markdown]
# DATA DICTONARY
#
# 1	Car_ID - 			   Unique id of each observation (Interger)
# 2	Symboling -  		   Its assigned insurance risk rating, A value of +3 indicates that the auto is risky, -3 that it is                               probably pretty safe.(Categorical)
# 3	carCompany -     		Name of car company (Categorical)
# 4	fueltype			Car fuel type i.e gas or diesel (Categorical)
# 5	aspiration			Aspiration used in a car (Categorical)
# 6	doornumber			Number of doors in a car (Categorical)
# 7	carbody			    body of car (Categorical)
# 8	drivewheel			type of drive wheel (Categorical)
# 9	enginelocation			Location of car engine (Categorical)
# 10	wheelbase			Weelbase of car (Numeric)
# 11	carlength			Length of car (Numeric)
# 12	carwidth			Width of car (Numeric)
# 13	carheight			height of car (Numeric)
# 14	curbweight			The weight of a car without occupants or baggage. (Numeric)
# 15	enginetype			Type of engine. (Categorical)
# 16	cylindernumber			cylinder placed in the car (Categorical)
# 17	enginesize			Size of car (Numeric)
# 18	fuelsystem			Fuel system of car (Categorical)
# 19	boreratio			Boreratio of car (Numeric)
# 20	stroke			Stroke or volume inside the engine (Numeric)
# 21	compressionratio			compression ratio of car (Numeric)
# 22	horsepower			Horsepower (Numeric)
# 23	peakrpm			car peak rpm (Numeric)
# 24	citympg			Mileage in city (Numeric)
# 25	highwaympg			Mileage on highway (Numeric)
# 26	price(Dependent variable)			Price of car (Numeric)

# %%
car = pd.read_csv('CarPrice_Assignment.csv')
car.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
car.shape
# Out:
# (205, 26)

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
car.describe()
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# ...

# %%
# Creating the heatmap
plt.figure(figsize = (15,15))
cor = car.corr()
sns.heatmap(cor, annot = True)
plt.show()

# %%
corr=car.corr()
corr.style.background_gradient(cmap="inferno")
# Out:
# <style  type="text/css" >
#     #T_b181b7b4_3522_11eb_971b_80913351c9earow0_col0 {
#             background-color:  #fcffa4;
#             color:  #000000;
#         }    #T_b181b7b4_3522_11eb_971b_80913351c9earow0_col1 {
#             background-color:  #57106e;
#             color:  #f1f1f1;
#         }    #T_b181b7b4_3522_11eb_971b_80913351c9earow0_col2 {
#             background-color:  #a22b62;
#             color:  #f1f1f1;
#         }    #T_b181b7b4_3522_11eb_971b_80913351c9earow0_col3 {
#             background-color:  #c03a51;
#             color:  #f1f1f1;
#         }    #T_b181b7b4_3522_11eb_971b_80913351c9earow0_col4 {
#             background-color:  #a22b62;
#             color:  #f1f1f1;
#         }    #T_b181b7b4_3522_11eb_971b_80913351c9earow0_col5 {
#             background-color:  #c13a50;
#             color:  #f1f1f1;
#         }    #T_b181b7b4_3522_11eb_971b_80913351c9earow0_col6 {
#             background-color:  #b43359;
#             color:  #f1f1f1;
# ...

# %% [raw]
# plt.figure(figsize=(15,15))
# sns.heatmap(data.corr(),annot=True,cmap='inferno',mask=np.triu(data.corr(),k=1))

# %%
#Correlation with output variable
cor_target = abs(cor["price"])
#Selecting highly correlated features
relevant_features = cor_target[cor_target>0.5]
relevant_features
# Out:
# wheelbase     0.577816
# carlength     0.682920
# carwidth      0.759325
# curbweight    0.835305
# enginesize    0.874145
# boreratio     0.553173
# horsepower    0.808139
# citympg       0.685751
# highwaympg    0.697599
# price         1.000000
# Name: price, dtype: float64

# %%
# To sort out different datatypes  
list1 = []
list2 = []
list3 = []
for i in car:
    if car[i].dtype == ('object'):
        list1.append(i)
    if car[i].dtype == ('int64'):
        list2.append(i)
    else:
        list3.append(i)
print(list1)
print(list2)
print(list3)
# Out:
# ['CarName', 'fueltype', 'aspiration', 'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'enginetype', 'cylindernumber', 'fuelsystem']
# ['car_ID', 'symboling', 'curbweight', 'enginesize', 'horsepower', 'peakrpm', 'citympg', 'highwaympg']
# ['CarName', 'fueltype', 'aspiration', 'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'wheelbase', 'carlength', 'carwidth', 'carheight', 'enginetype', 'cylindernumber', 'fuelsystem', 'boreratio', 'stroke', 'compressionratio', 'price']

# %%
car.fueltype.value_counts()
# Out:
# gas       185
# diesel     20
# Name: fueltype, dtype: int64

# %%
car.aspiration.value_counts()
# Out:
# std      168
# turbo     37
# Name: aspiration, dtype: int64

# %%
car.doornumber.value_counts()
# Out:
# four    115
# two      90
# Name: doornumber, dtype: int64

# %%
car.carbody.value_counts()
# Out:
# sedan          96
# hatchback      70
# wagon          25
# hardtop         8
# convertible     6
# Name: carbody, dtype: int64

# %%
car.drivewheel.value_counts()
# Out:
# fwd    120
# rwd     76
# 4wd      9
# Name: drivewheel, dtype: int64

# %%
car.enginelocation.value_counts()
# Out:
# front    202
# rear       3
# Name: enginelocation, dtype: int64

# %%
car.enginetype.value_counts()
# Out:
# ohc      148
# ohcf      15
# ohcv      13
# l         12
# dohc      12
# rotor      4
# dohcv      1
# Name: enginetype, dtype: int64

# %%
car.cylindernumber.value_counts()
# Out:
# four      159
# six        24
# five       11
# eight       5
# two         4
# twelve      1
# three       1
# Name: cylindernumber, dtype: int64

# %%
car.fuelsystem.value_counts()
# Out:
# mpfi    94
# 2bbl    66
# idi     20
# 1bbl    11
# spdi     9
# 4bbl     3
# spfi     1
# mfi      1
# Name: fuelsystem, dtype: int64

# %%
# Removing feature Car Id.
car = car.drop(['car_ID'],axis=1, inplace = True)
car.head(2)
# Out:
#    symboling              CarName fueltype aspiration doornumber      carbody  \
# 0          3   alfa-romero giulia      gas        std        two  convertible
# 1          3  alfa-romero stelvio      gas        std        two  convertible
#
#   drivewheel enginelocation  wheelbase  carlength  ...  enginesize  \
# 0        rwd          front       88.6      168.8  ...         130
# 1        rwd          front       88.6      168.8  ...         130
#
#    fuelsystem  boreratio stroke compressionratio  horsepower peakrpm  citympg  \
# 0        mpfi       3.47   2.68              9.0         111    5000       21
# 1        mpfi       3.47   2.68              9.0         111    5000       21
#
#    highwaympg    price
# 0          27  13495.0
# 1          27  16500.0
#
# [2 rows x 25 columns]

# %%
# Extracting Car Company from Car Name
car['CarName'] = car['CarName'].str.split(' ',expand=True)
car.head()
# Out:
#    symboling      CarName fueltype aspiration doornumber      carbody  \
# 0          3  alfa-romero      gas        std        two  convertible
# 1          3  alfa-romero      gas        std        two  convertible
# 2          1  alfa-romero      gas        std        two    hatchback
# 3          2         audi      gas        std       four        sedan
# 4          2         audi      gas        std       four        sedan
#
#   drivewheel enginelocation  wheelbase  carlength  ...  enginesize  \
# 0        rwd          front       88.6      168.8  ...         130
# 1        rwd          front       88.6      168.8  ...         130
# 2        rwd          front       94.5      171.2  ...         152
# 3        fwd          front       99.8      176.6  ...         109
# 4        4wd          front       99.4      176.6  ...         136
#
#    fuelsystem  boreratio stroke compressionratio  horsepower peakrpm  citympg  \
# ...

# %%
# Handling duplicate values in the car name such as Nissan and nissan are same, toyota and toyouta are same.
# vokswagen, volkswagen and vw are same, mazda and maxda are same, porcshce and porsche are same.
car['CarName'] = car['CarName'].replace({'maxda': 'mazda', 'nissan': 'Nissan', 'porcshce': 'porsche', 'toyouta': 'toyota', 
                                            'vokswagen': 'volkswagen', 'vw': 'volkswagen'})

# %%
# Changing datatype of feature symboling
car['symboling']=car['symboling'].astype('str')

# %%
# Categorical Columns
cat_col = car.select_dtypes(include = ['object']).columns

# %%
car[cat_col].head(2)
# Out:
#   symboling      CarName fueltype aspiration doornumber      carbody  \
# 0         3  alfa-romero      gas        std        two  convertible
# 1         3  alfa-romero      gas        std        two  convertible
#
#   drivewheel enginelocation enginetype cylindernumber fuelsystem
# 0        rwd          front       dohc           four       mpfi
# 1        rwd          front       dohc           four       mpfi

# %%
# Numerical Columns
num_col = car.select_dtypes(exclude = ['object']).columns

# %%
car[num_col].head(2)
# Out:
#    wheelbase  carlength  carwidth  carheight  curbweight  enginesize  \
# 0       88.6      168.8      64.1       48.8        2548         130
# 1       88.6      168.8      64.1       48.8        2548         130
#
#    boreratio  stroke  compressionratio  horsepower  peakrpm  citympg  \
# 0       3.47    2.68               9.0         111     5000       21
# 1       3.47    2.68               9.0         111     5000       21
#
#    highwaympg    price
# 0          27  13495.0
# 1          27  16500.0

# %% [markdown]
# ##  Visualizations

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   symboling         205 non-null    object
#  1   CarName           205 non-null    object
#  2   fueltype          205 non-null    object
#  3   aspiration        205 non-null    object
#  4   doornumber        205 non-null    object
#  5   carbody           205 non-null    object
#  6   drivewheel        205 non-null    object
#  7   enginelocation    205 non-null    object
#  8   wheelbase         205 non-null    float64
#  9   carlength         205 non-null    float64
#  10  carwidth          205 non-null    float64
#  11  carheight         205 non-null    float64
#  12  curbweight        205 non-null    int64
#  13  enginetype        205 non-null    object
#  14  cylindernumber    205 non-null    object
#  15  enginesize        205 non-null    int64
# ...

# %%
# To sort out different datatypes  
list1 = []
list2 = []
list3 = []
for i in car:
    if car[i].dtype == ('object'):
        list1.append(i)
    if car[i].dtype == ('int64'):
        list2.append(i)
    else:
        list3.append(i)
print(list1)
print(list2)
print(list3)
# Out:
# ['symboling', 'CarName', 'fueltype', 'aspiration', 'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'enginetype', 'cylindernumber', 'fuelsystem']
# ['curbweight', 'enginesize', 'horsepower', 'peakrpm', 'citympg', 'highwaympg']
# ['symboling', 'CarName', 'fueltype', 'aspiration', 'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'wheelbase', 'carlength', 'carwidth', 'carheight', 'enginetype', 'cylindernumber', 'fuelsystem', 'boreratio', 'stroke', 'compressionratio', 'price']

# %%
sns.set(font_scale=1.6)
plt.figure(figsize =(40,20))
sns.countplot(x = 'CarName', data=car)
plt.xticks(rotation = 45)
plt.show()

# %%
df=pd.DataFrame(car['CarName'].value_counts()).reset_index().rename(columns={'index':'car_name','CarName': 'count'})

# %%
plot = sns.barplot(y='car_name',x='count',data=df)
plot=plt.setp(plot.get_xticklabels(), rotation=80)
# According to the dataset: Toyota is the most suitable car & Mercury is the least suitable car

# %%
sns.set(font_scale=1.6)
plt.figure(figsize =(40,20))
sns.countplot(x = 'symboling', data=car)
plt.xticks(rotation = 45)
plt.show()

# %%
sns.set(font_scale=1.6)
plt.figure(figsize =(10,10))
sns.countplot(x = 'fueltype', data=car)
plt.xticks(rotation = 45)
plt.show()
# most of the car have gas fuel.
# Price of diesel is much higher than of gas , also there are some outliers in gas vehicles

# %%
sns.set(font_scale=1.6)
plt.figure(figsize =(10,10))
sns.countplot(x = 'doornumber', data=car)
plt.xticks(rotation = 45)
plt.show()

# %%
sns.set(font_scale=1.6)
plt.figure(figsize =(10,10))
sns.countplot(x = 'aspiration', data=car)
plt.xticks(rotation = 45)
plt.show()
# Most of the car have standard aspiration.

# %%
sns.set(font_scale=1.6)
plt.figure(figsize =(10,10))
sns.countplot(x = 'carbody', data=car)
plt.xticks(rotation = 45)
plt.show()

# %%
sns.set(font_scale=1.6)
plt.figure(figsize =(10,10))
sns.countplot(x = 'drivewheel', data=car)
plt.xticks(rotation = 45)
plt.show()

# %%
sns.set(font_scale=1.6)
plt.figure(figsize =(10,10))
sns.countplot(x = 'enginelocation', data=car)
plt.xticks(rotation = 45)
plt.show()

# %%
sns.set(font_scale=1.6)
plt.figure(figsize =(10,10))
sns.countplot(x = 'fuelsystem', data=car)
plt.xticks(rotation = 45)
plt.show()

# %%
# To sort out different datatypes  
list1 = []
list2 = []
list3 = []
for i in car:
    if car[i].dtype == ('object'):
        list1.append(i)
    if car[i].dtype == ('int64'):
        list2.append(i)
    else:
        list3.append(i)
print(list1)
print(list2)
print(list3)
# Out:
# ['symboling', 'CarName', 'fueltype', 'aspiration', 'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'enginetype', 'cylindernumber', 'fuelsystem']
# ['curbweight', 'enginesize', 'horsepower', 'peakrpm', 'citympg', 'highwaympg']
# ['symboling', 'CarName', 'fueltype', 'aspiration', 'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'wheelbase', 'carlength', 'carwidth', 'carheight', 'enginetype', 'cylindernumber', 'fuelsystem', 'boreratio', 'stroke', 'compressionratio', 'price']

# %%
col=['wheelbase','carlength','carwidth','curbweight','price']

# %%
sns.pairplot(car[col])
plt.show()

# %%
sns.pairplot(car[['horsepower','price','carbody']], hue="carbody")
plt.show()

# %% [raw]
# f= plt.figure(figsize=(12,5))
#
# ax=f.add_subplot(121)
# sns.distplot(data[(data.fueltype== 'gas')]["price"],color='b',ax=ax)
# ax.set_title('Distribution of price of gas vehicles')
#
# ax=f.add_subplot(122)
# sns.distplot(data[(data.fueltype == 'diesel')]['price'],color='r',ax=ax)
# ax.set_title('Distribution of ages of diesel vehicles')

# %%
plt.figure(figsize = (10,10))
sns.distplot(car.price, color = 'blue', kde = True)
plt.show()
# Price distribution plot is right skewed
# Maximum number of cars are in range of 20000

# %%
plt.figure(figsize = (10,10))
sns.distplot(car.symboling, color = 'red', kde = True)
plt.show()

# %%
plt.figure(figsize = (10,10))
sns.distplot(car.curbweight, color = 'yellow', kde = True)
plt.show()

# %%
plt.figure(figsize = (10,10))
sns.distplot(car.enginesize, color = 'green', kde = True)
plt.show()

# %%
plt.figure(figsize = (10,10))
sns.distplot(car.horsepower, color = 'pink', kde = True)
plt.show()

# %%
plt.figure(figsize = (10,10))
sns.distplot(car.peakrpm, color = 'black', kde = True)
plt.show()
plt.figure(figsize = (10,10))
sns.distplot(car.citympg, color = 'magenta', kde = True)
plt.show()
plt.figure(figsize = (10,10))
sns.distplot(car.highwaympg, color = 'darkblue', kde = True)
plt.show()

# %% [raw]
# plt.figure(figsize = (10,10))
# sns.distplot(car.car_ID, color = 'darkblue', kde = True)
# plt.show()

# %%
list1 = []
list2 = []
list3 = []
for i in car:
    if car[i].dtype == ('object'):
        list1.append(i)
    if car[i].dtype == ('int64'):
        list2.append(i)
    else:
        list3.append(i)
print(list1)
print(list2)
print(list3)
# Out:
# ['symboling', 'CarName', 'fueltype', 'aspiration', 'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'enginetype', 'cylindernumber', 'fuelsystem']
# ['curbweight', 'enginesize', 'horsepower', 'peakrpm', 'citympg', 'highwaympg']
# ['symboling', 'CarName', 'fueltype', 'aspiration', 'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'wheelbase', 'carlength', 'carwidth', 'carheight', 'enginetype', 'cylindernumber', 'fuelsystem', 'boreratio', 'stroke', 'compressionratio', 'price']

# %%
car.head()
# Out:
#   symboling      CarName fueltype aspiration doornumber      carbody  \
# 0         3  alfa-romero      gas        std        two  convertible
# 1         3  alfa-romero      gas        std        two  convertible
# 2         1  alfa-romero      gas        std        two    hatchback
# 3         2         audi      gas        std       four        sedan
# 4         2         audi      gas        std       four        sedan
#
#   drivewheel enginelocation  wheelbase  carlength  ...  enginesize  \
# 0        rwd          front       88.6      168.8  ...         130
# 1        rwd          front       88.6      168.8  ...         130
# 2        rwd          front       94.5      171.2  ...         152
# 3        fwd          front       99.8      176.6  ...         109
# 4        4wd          front       99.4      176.6  ...         136
#
#    fuelsystem  boreratio stroke compressionratio  horsepower peakrpm  citympg  \
# ...

# %%
car.columns
# Out:
# Index(['symboling', 'CarName', 'fueltype', 'aspiration', 'doornumber',
#        'carbody', 'drivewheel', 'enginelocation', 'wheelbase', 'carlength',
#        'carwidth', 'carheight', 'curbweight', 'enginetype', 'cylindernumber',
#        'enginesize', 'fuelsystem', 'boreratio', 'stroke', 'compressionratio',
#        'horsepower', 'peakrpm', 'citympg', 'highwaympg', 'price'],
#       dtype='object')

# %%
plt.figure(figsize = (10,10))
sns.distplot(car.wheelbase, color = 'black', kde = True)
plt.show()
plt.figure(figsize = (10,10))
sns.distplot(car.carlength, color = 'red', kde = True)
plt.show()
plt.figure(figsize = (10,10))
sns.distplot(car.carwidth, color = 'green', kde = True)
plt.show()
plt.figure(figsize = (10,10))
sns.distplot(car.carheight, color = 'blue', kde = True)
plt.show()
plt.figure(figsize = (10,10))
sns.distplot(car.boreratio, color = 'orange', kde = True)
plt.show()
plt.figure(figsize = (10,10))
sns.distplot(car.stroke, color = 'darkblue', kde = True)
plt.show()
plt.figure(figsize = (10,10))
sns.distplot(car.compressionratio, color = 'magenta', kde = True)
plt.show()

# %%
list1 = []
list2 = []
list3 = []
for i in car:
    if car[i].dtype == ('object'):
        list1.append(i)
    if car[i].dtype == ('int64'):
        list2.append(i)
    else:
        list3.append(i)
print(list1)
print(list2)
print(list3)
# Out:
# ['symboling', 'CarName', 'fueltype', 'aspiration', 'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'enginetype', 'cylindernumber', 'fuelsystem']
# ['curbweight', 'enginesize', 'horsepower', 'peakrpm', 'citympg', 'highwaympg']
# ['symboling', 'CarName', 'fueltype', 'aspiration', 'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'wheelbase', 'carlength', 'carwidth', 'carheight', 'enginetype', 'cylindernumber', 'fuelsystem', 'boreratio', 'stroke', 'compressionratio', 'price']

# %% [markdown]
# ## Bivariate Analysis

# %%
# Scatter Plot (Numerical & Numerical)
plt.figure(figsize = [10,6])
plt.scatter(car.horsepower , car.price , color = 'green')
plt.xlabel('Horsepower')
plt.ylabel('Price')
plt.show()

# %%
# Scatter Plot (Numerical & Numerical)
plt.figure(figsize = [10,6])
plt.scatter(car.peakrpm , car.price , color = 'black')
plt.xlabel('Peakrpmr')
plt.ylabel('Price')
plt.show()

# %%
# Scatter Plot (Numerical & Numerical)
plt.figure(figsize = [10,6])
plt.scatter(car.citympg , car.price , color = 'red')
plt.xlabel('CityMPG')
plt.ylabel('Price')
plt.show()

# %%
# Scatter Plot (Numerical & Numerical)
plt.figure(figsize = [10,6])
plt.scatter(car.highwaympg , car.price , color = 'yellow')
plt.xlabel('HighwayMPG')
plt.ylabel('Price')
plt.show()

# %%
# Scatter Plot (Numerical & Numerical)
plt.figure(figsize = [10,6])
plt.scatter(car.symboling , car.price , color = 'pink')
plt.xlabel('Symboling')
plt.ylabel('Price')
plt.show()

# %%
list1 = []
list2 = []
list3 = []
for i in car:
    if car[i].dtype == ('object'):
        list1.append(i)
    if car[i].dtype == ('int64'):
        list2.append(i)
    else:
        list3.append(i)
print(list1)
print(list2)
print(list3)
# Out:
# ['symboling', 'CarName', 'fueltype', 'aspiration', 'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'enginetype', 'cylindernumber', 'fuelsystem']
# ['curbweight', 'enginesize', 'horsepower', 'peakrpm', 'citympg', 'highwaympg']
# ['symboling', 'CarName', 'fueltype', 'aspiration', 'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'wheelbase', 'carlength', 'carwidth', 'carheight', 'enginetype', 'cylindernumber', 'fuelsystem', 'boreratio', 'stroke', 'compressionratio', 'price']

# %% [raw]
# DATA DICTONARY
#
# 1	Car_ID - 			   Unique id of each observation (Interger)
# 2	Symboling -  		   Its assigned insurance risk rating, A value of +3 indicates that the auto is risky, -3 that it is                               probably pretty safe.(Categorical)
# 3	carCompany -     		Name of car company (Categorical)
# 4	fueltype			Car fuel type i.e gas or diesel (Categorical)
# 5	aspiration			Aspiration used in a car (Categorical)
# 6	doornumber			Number of doors in a car (Categorical)
# 7	carbody			    body of car (Categorical)
# 8	drivewheel			type of drive wheel (Categorical)
# 9	enginelocation			Location of car engine (Categorical)
# 10	wheelbase			Wheelbase of car (Numeric)
# 11	carlength			Length of car (Numeric)
# 12	carwidth			Width of car (Numeric)
# 13	carheight			height of car (Numeric)
# 14	curbweight			The weight of a car without occupants or baggage. (Numeric)
# 15	enginetype			Type of engine. (Categorical)
# 16	cylindernumber			cylinder placed in the car (Categorical)
# 17	enginesize			Size of car (Numeric)
# 18	fuelsystem			Fuel system of car (Categorical)
# 19	boreratio			Boreratio of car (Numeric)
# 20	stroke			Stroke or volume inside the engine (Numeric)
# 21	compressionratio			compression ratio of car (Numeric)
# 22	horsepower			Horsepower (Numeric)
# 23	peakrpm			car peak rpm (Numeric)
# 24	citympg			Mileage in city (Numeric)
# 25	highwaympg			Mileage on highway (Numeric)
# 26	price(Dependent variable)			Price of car (Numeric)

# %%
# Scatter Plot (Numerical & Numerical)
plt.figure(figsize = [10,6])
plt.scatter(car.wheelbase , car.price , color = 'red')
plt.xlabel('Wheelbase')
plt.ylabel('Price')
plt.show()

# %%
# Scatter Plot (Numerical & Numerical)
plt.figure(figsize = [10,6])
plt.scatter(car.carlength , car.price , color = 'black')
plt.xlabel('CarLength')
plt.ylabel('Price')
plt.show()

# %%
# Scatter Plot (Numerical & Numerical)
plt.figure(figsize = [10,6])
plt.scatter(car.carwidth , car.price , color = 'orange')
plt.xlabel('CarWidth')
plt.ylabel('Price')
plt.show()

# %%
# Scatter Plot (Numerical & Numerical)
plt.figure(figsize = [10,6])
plt.scatter(car.carheight , car.price , color = 'green')
plt.xlabel('CarHeight')
plt.ylabel('Price')
plt.show()

# %%
# Scatter Plot (Numerical & Numerical)
plt.figure(figsize = [10,6])
plt.scatter(car.boreratio , car.price , color = 'purple')
plt.xlabel('Boreratio')
plt.ylabel('Price')
plt.show()

# %%
# Scatter Plot (Numerical & Numerical)
plt.figure(figsize = [10,6])
plt.scatter(car.stroke , car.price , color = 'yellow')
plt.xlabel('Stroke')
plt.ylabel('Price')
plt.show()

# %%
# Scatter Plot (Numerical & Numerical)
plt.figure(figsize = [10,6])
plt.scatter(car.compressionratio , car.price , color = 'blue')
plt.xlabel('CompressionRatio')
plt.ylabel('Price')
plt.show()

# %%
list1 = []
list2 = []
list3 = []
for i in car:
    if car[i].dtype == ('object'):
        list1.append(i)
    if car[i].dtype == ('int64'):
        list2.append(i)
    else:
        list3.append(i)
print(list1)
print(list2)
print(list3)
# Out:
# ['symboling', 'CarName', 'fueltype', 'aspiration', 'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'enginetype', 'cylindernumber', 'fuelsystem']
# ['curbweight', 'enginesize', 'horsepower', 'peakrpm', 'citympg', 'highwaympg']
# ['symboling', 'CarName', 'fueltype', 'aspiration', 'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'wheelbase', 'carlength', 'carwidth', 'carheight', 'enginetype', 'cylindernumber', 'fuelsystem', 'boreratio', 'stroke', 'compressionratio', 'price']

# %% [raw]
# sns.boxplot(x = 'symboling', y = 'price', data = data,palette='Pastel1')

# %% [raw]
# f= plt.figure(figsize=(12,5))
#
# ax=f.add_subplot(121)
# plot=sns.distplot(data[(data.doornumber== 'two')]["price"],color='#ca91eb',ax=ax)
# ax.set_title('Price distribution of cars having two doors')
#
# ax=f.add_subplot(122)
# plot=sns.distplot(data[(data.doornumber == 'four')]['price'],color='#eb6426',ax=ax)
# ax.set_title('Price distribution of cars having four doors')

# %% [raw]
# g = sns.jointplot(x="curbweight", y="price", data=data, kind="kde", color="b")
# g.plot_joint(plt.scatter, c="w", s=30, linewidth=1, marker="+")
# g.ax_joint.collections[0].set_alpha(0)
# g.set_axis_labels("curbweight", "price");

# %%
# Boxplot   (Numerical & Catagorical)
plt.figure(figsize = [10,6])
sns.boxplot(x = 'carbody', y = 'price', data = car)
plt.show()

# %%
# Boxplot   (Numerical & Catagorical)
plt.figure(figsize = [10,6])
sns.boxplot(x = 'symboling', y = 'price', data = car)
plt.show()

# %%
# Boxplot   (Numerical & Catagorical)
plt.figure(figsize = [10,6])
sns.boxplot(x = 'doornumber', y = 'price', data = car)
plt.show()

# %%
# Boxplot   (Numerical & Catagorical)
plt.figure(figsize = [10,6])
sns.boxplot(x = 'aspiration', y = 'price', data = car)
plt.show()

# %%
# Boxplot   (Numerical & Catagorical)
plt.figure(figsize = [10,6])
sns.boxplot(x = 'fueltype', y = 'price', data = car)
plt.show()

# %%
# Boxplot   (Numerical & Catagorical)
plt.figure(figsize = [20,10])
sns.boxplot(x = 'CarName', y = 'price', data = car)
plt.show()

# %%
# Boxplot   (Numerical & Catagorical)
plt.figure(figsize = [10,6])
sns.boxplot(x = 'drivewheel', y = 'price', data = car)
plt.show()

# %%
# Boxplot   (Numerical & Catagorical)
plt.figure(figsize = [10,6])
sns.boxplot(x = 'enginelocation', y = 'price', data = car)
plt.show()

# %%
# Boxplot   (Numerical & Catagorical)
plt.figure(figsize = [10,6])
sns.boxplot(x = 'enginetype', y = 'price', data = car)
plt.show()

# %%
# Boxplot   (Numerical & Catagorical)
plt.figure(figsize = [10,6])
sns.boxplot(x = 'cylindernumber', y = 'price', data = car)
plt.show()

# %%
# Boxplot   (Numerical & Catagorical)
plt.figure(figsize = [10,6])
sns.boxplot(x = 'fuelsystem', y = 'price', data = car)
plt.show()

# %%
list1 = []
list2 = []
list3 = []
for i in car:
    if car[i].dtype == ('object'):
        list1.append(i)
    if car[i].dtype == ('int64'):
        list2.append(i)
    else:
        list3.append(i)
print(list1)
print(list2)
print(list3)
# Out:
# ['symboling', 'CarName', 'fueltype', 'aspiration', 'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'enginetype', 'cylindernumber', 'fuelsystem']
# ['curbweight', 'enginesize', 'horsepower', 'peakrpm', 'citympg', 'highwaympg']
# ['symboling', 'CarName', 'fueltype', 'aspiration', 'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'wheelbase', 'carlength', 'carwidth', 'carheight', 'enginetype', 'cylindernumber', 'fuelsystem', 'boreratio', 'stroke', 'compressionratio', 'price']

# %%
# CrossTab (Catagorical & Catagorical)
pd.crosstab(car.fueltype, car.carbody)
# Out:
# carbody   convertible  hardtop  hatchback  sedan  wagon
# fueltype
# diesel              0        1          1     15      3
# gas                 6        7         69     81     22

# %%
pd.crosstab(car.symboling, car.carbody)
# Out:
# carbody    convertible  hardtop  hatchback  sedan  wagon
# symboling
# -1                   0        0          2     13      7
# -2                   0        0          0      3      0
# 0                    0        1          8     43     15
# 1                    0        1         27     23      3
# 2                    1        4         13     14      0
# 3                    5        2         20      0      0

# %%
pd.crosstab(car.drivewheel, car.enginelocation)
# Out:
# enginelocation  front  rear
# drivewheel
# 4wd                 9     0
# fwd               120     0
# rwd                73     3

# %%
pd.crosstab(car.drivewheel, car.symboling)
# Out:
# symboling   -1  -2   0   1   2   3
# drivewheel
# 4wd          0   0   7   0   2   0
# fwd          8   0  35  44  22  11
# rwd         14   3  25  10   8  16

# %%
pd.crosstab(car.symboling, car.enginelocation).T
# Out:
# symboling       -1  -2   0   1   2   3
# enginelocation
# front           22   3  67  54  32  24
# rear             0   0   0   0   0   3

# %%
pd.crosstab(car.fueltype, car.enginetype)
# Out:
# enginetype  dohc  dohcv  l  ohc  ohcf  ohcv  rotor
# fueltype
# diesel         0      0  5   15     0     0      0
# gas           12      1  7  133    15    13      4

# %%
pd.crosstab(car.fueltype, car.fuelsystem)
# Out:
# fuelsystem  1bbl  2bbl  4bbl  idi  mfi  mpfi  spdi  spfi
# fueltype
# diesel         0     0     0   20    0     0     0     0
# gas           11    66     3    0    1    94     9     1

# %%
pd.crosstab(car.enginetype, car.cylindernumber)
# Out:
# cylindernumber  eight  five  four  six  three  twelve  two
# enginetype
# dohc                0     0     6    6      0       0    0
# dohcv               1     0     0    0      0       0    0
# l                   0     0    11    0      1       0    0
# ohc                 0    11   130    7      0       0    0
# ohcf                0     0    12    3      0       0    0
# ohcv                4     0     0    8      0       1    0
# rotor               0     0     0    0      0       0    4

# %%
pd.crosstab(car.carbody, car.drivewheel).T
# Out:
# carbody     convertible  hardtop  hatchback  sedan  wagon
# drivewheel
# 4wd                   0        0          2      3      4
# fwd                   1        1         49     57     12
# rwd                   5        7         19     36      9

# %%
pd.crosstab(car.carbody, car.doornumber).T
# Out:
# carbody     convertible  hardtop  hatchback  sedan  wagon
# doornumber
# four                  0        0         10     80     25
# two                   6        8         60     16      0

# %%
pd.crosstab(car.carbody, car.aspiration).T
# Out:
# carbody     convertible  hardtop  hatchback  sedan  wagon
# aspiration
# std                   6        7         57     78     20
# turbo                 0        1         13     18      5

# %%
pd.crosstab(car.symboling, car.aspiration).T
# Out:
# symboling   -1  -2   0   1   2   3
# aspiration
# std         14   2  56  47  30  19
# turbo        8   1  11   7   2   8

# %%
pd.crosstab(car.CarName, car.carbody).T
# Out:
# CarName      Nissan  alfa-romero  audi  bmw  buick  chevrolet  dodge  honda  \
# carbody
# convertible       0            2     0    0      1          0      0      0
# hardtop           1            0     0    0      2          0      0      0
# hatchback         5            1     1    0      0          2      5      7
# sedan             9            0     5    8      4          1      3      5
# wagon             3            0     1    0      1          0      1      1
#
# CarName      isuzu  jaguar  ...  mitsubishi  peugeot  plymouth  porsche  \
# carbody                     ...
# convertible      0       0  ...           0        0         0        1
# hardtop          0       0  ...           0        0         0        2
# hatchback        1       0  ...           9        0         4        2
# sedan            3       3  ...           4        7         2        0
# wagon            0       0  ...           0        4         1        0
#
# ...

# %% [raw]
# fig,axes = plt.subplots(4,4,figsize=(18,15))
# for seg,col in enumerate(numerical_cols[:len(numerical_cols)-1]):
#
#     x,y = seg//4,seg%4
#     sns.regplot(x=col, y='price' ,data=data,ax=axes[x][y],color='r')

# %% [markdown]
# # Missing Values Treatment

# %%
car.isnull().sum()
# Out:
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
car.isnull().sum()[car.isnull().sum()!=0]
# Out:
# Series([], dtype: int64)

# %%
import missingno as msno
msno.dendrogram(car)
# Out:
# C:\Users\ADITYA GUPTA\anaconda3\lib\site-packages\scipy\cluster\hierarchy.py:2833: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   ax.set_ylim([dvw, 0])

# %%
car.columns
# Out:
# Index(['symboling', 'CarName', 'fueltype', 'aspiration', 'doornumber',
#        'carbody', 'drivewheel', 'enginelocation', 'wheelbase', 'carlength',
#        'carwidth', 'carheight', 'curbweight', 'enginetype', 'cylindernumber',
#        'enginesize', 'fuelsystem', 'boreratio', 'stroke', 'compressionratio',
#        'horsepower', 'peakrpm', 'citympg', 'highwaympg', 'price'],
#       dtype='object')

# %% [markdown]
# ### Handling Outliers

# %%
sns.boxplot(car['enginesize'],color='red')
plt.show()
sns.boxplot(car['highwaympg'],color='red')
plt.show()
sns.boxplot(car['citympg'],color='red')
plt.show()
sns.boxplot(car['peakrpm'],color='red')
plt.show()
sns.boxplot(car['horsepower'],color='red')
plt.show()
sns.boxplot(car['compressionratio'],color='red')
plt.show()
sns.boxplot(car['boreratio'],color='red')
plt.show()
sns.boxplot(car['stroke'],color='red')
plt.show()
sns.boxplot(car['wheelbase'],color='red')
plt.show()
sns.boxplot(car['carlength'],color='red')
plt.show()
sns.boxplot(car['carwidth'],color='red')
plt.show()
sns.boxplot(car['carheight'],color='red')
plt.show()
sns.boxplot(car['curbweight'],color='red')
plt.show()

# %%
car['enginesize']=car['enginesize'].rank()
car['highwaympg']=car['highwaympg'].rank()
car['citympg']=car['citympg'].rank()
car['peakrpm']=car['peakrpm'].rank()
car['horsepower']=car['horsepower'].rank()
car['compressionratio']=car['compressionratio'].rank()
car['stroke']=car['stroke'].rank()
car['wheelbase']=car['wheelbase'].rank()
car['carlength']=car['carlength'].rank()
car['carwidth']=car['carwidth'].rank()

# %%
sns.boxplot(car['enginesize'],color='red')
plt.show()
sns.boxplot(car['highwaympg'],color='red')
plt.show()
sns.boxplot(car['citympg'],color='red')
plt.show()
sns.boxplot(car['peakrpm'],color='red')
plt.show()
sns.boxplot(car['horsepower'],color='red')
plt.show()
sns.boxplot(car['compressionratio'],color='red')
plt.show()
sns.boxplot(car['stroke'],color='red')
plt.show()
sns.boxplot(car['wheelbase'],color='red')
plt.show()
sns.boxplot(car['carlength'],color='red')
plt.show()
sns.boxplot(car['carwidth'],color='red')
plt.show()

# %% [markdown]
# ### Model Building

# %%
car1 = car.copy()

# %%
car1.columns
# Out:
# Index(['symboling', 'CarName', 'fueltype', 'aspiration', 'doornumber',
#        'carbody', 'drivewheel', 'enginelocation', 'wheelbase', 'carlength',
#        'carwidth', 'carheight', 'curbweight', 'enginetype', 'cylindernumber',
#        'enginesize', 'fuelsystem', 'boreratio', 'stroke', 'compressionratio',
#        'horsepower', 'peakrpm', 'citympg', 'highwaympg', 'price'],
#       dtype='object')

# %% [raw]
# x = car1.drop(columns = ['car_ID','price'], axis=1)
# y = car1['price']

# %% [raw]
# ## Spiltting the data into train and test
# from sklearn.model_selection import train_test_split
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.30, random_state = 123)
# print(x_train.shape)
# print(x_test.shape)
# print(y_train.shape)
# print(y_test.shape)

# %% [raw]
# list1 = []
# list2 = []
# list3 = []
# for i in car1:
#     if car1[i].dtype == ('object'):
#         list1.append(i)
#     if car1[i].dtype == ('int64'):
#         list2.append(i)
#     else:
#         list3.append(i)
# print(list1)
# print(list2)
# print(list3)

# %% [raw]
# from sklearn.preprocessing import LabelEncoder
# le=LabelEncoder()
# car1['fuelsystem']=le.fit_transform(car1['fuelsystem'])
# car1['cylindernumber']=le.fit_transform(car1['cylindernumber'])
# car1['enginetype']=le.fit_transform(car1['enginetype'])
# car1['enginelocation']=le.fit_transform(car1['enginelocation'])
# car1['drivewheel']=le.fit_transform(car1['drivewheel'])
# car1['carbody']=le.fit_transform(car1['carbody'])
# car1['doornumber']=le.fit_transform(car1['doornumber'])
# car1['aspiration']=le.fit_transform(car1['aspiration'])
# car1['fueltype']=le.fit_transform(car1['fueltype'])
# car1['CarName']=le.fit_transform(car1['CarName'])

# %% [raw]
# from sklearn.linear_model import LinearRegression
# lin_reg = LinearRegression()
# lin_reg.fit(x,y)
#
# print(f'Coefficients: {lin_reg.coef_}')
# print(f'Intercept: {lin_reg.intercept_}')
# print(f'R^2 score: {lin_reg.score(x, y)}')

# %% [markdown]
# ### Model Building - Feature Selection

# %%
X = car1[num_col].drop('price',axis=1)
y = car1['price']

# %% [markdown]
# #### Recursive Feature Elimination with Random Forest Regressor

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
car1['fuelsystem']=le.fit_transform(car1['fuelsystem'])
car1['cylindernumber']=le.fit_transform(car1['cylindernumber'])
car1['enginetype']=le.fit_transform(car1['enginetype'])
car1['enginelocation']=le.fit_transform(car1['enginelocation'])
car1['drivewheel']=le.fit_transform(car1['drivewheel'])
car1['carbody']=le.fit_transform(car1['carbody'])
car1['doornumber']=le.fit_transform(car1['doornumber'])
car1['aspiration']=le.fit_transform(car1['aspiration'])
car1['fueltype']=le.fit_transform(car1['fueltype'])
car1['CarName']=le.fit_transform(car1['CarName'])

# %%
X = car1.drop(columns = ['CarName','price'], axis=1)
y = car1['price']

# %%
# Create the RFE object and rank each pixel
from sklearn.feature_selection import RFE
from sklearn.ensemble import RandomForestRegressor
clf_rf_3 = RandomForestRegressor()      
rfe = RFE(estimator=clf_rf_3, n_features_to_select=15, step=1)
rfe = rfe.fit(X, y)
print('Chosen best 15 feature by rfe:',X.columns[rfe.support_])
# Out:
# Chosen best 15 feature by rfe: Index(['carbody', 'wheelbase', 'carlength', 'carwidth', 'carheight',
#        'curbweight', 'enginesize', 'fuelsystem', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg'],
#       dtype='object')

# %%
features=list(X.columns[rfe.support_])

# %% [markdown]
# ### DataModelling and Evaluation

# %%
x = X[features]
y = car1.price
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.30, random_state = 0)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (143, 15)
# (62, 15)
# (143,)
# (62,)

# %%
from sklearn.linear_model import LinearRegression
lreg = LinearRegression()
lreg.fit(x_train,y_train)
y_train_pred = lreg.predict(x_train)
y_test_pred = lreg.predict(x_test)
lreg.score(x_test,y_test)
# Out:
# 0.7308603087686485

# %%
from sklearn.tree import DecisionTreeRegressor
dt_regressor = DecisionTreeRegressor(random_state=0)
dt_regressor.fit(x_train,y_train)
y_train_pred = dt_regressor.predict(x_train)
y_test_pred = dt_regressor.predict(x_test)
dt_regressor.score(x_test,y_test)
# Out:
# 0.8703807948773999

# %%
from sklearn.ensemble import RandomForestRegressor
Rf = RandomForestRegressor(n_estimators = 15,
                              criterion = 'mse',
                              random_state = 20,
                              n_jobs = -1)
Rf.fit(x_train,y_train)
Rf_train_pred = Rf.predict(x_train)
Rf_test_pred = Rf.predict(x_test)
from sklearn.metrics import r2_score

r2_score(y_test,Rf_test_pred)
# Out:
# 0.8973138905497436

# %% [markdown]
# Conclusion
#
# We applied three models Linear Regression, Decision Tree Regressor,and Random Forest Regressor
#
# We can clearly see that Random forest regressor is giving best in comparison to other models.  Accuracy is  approx 90%.
